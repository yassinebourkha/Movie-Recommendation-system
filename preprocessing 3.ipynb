# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Extracting features of 2018 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                       Title  \
# 0      J A N U A R Y          5     Insidious: The Last Key
# 1      J A N U A R Y          5            The Strange Ones
# 2      J A N U A R Y          5                    Stratton
# 3      J A N U A R Y         10               Sweet Country
# 4      J A N U A R Y         12                The Commuter
# ..               ...        ...                         ...
# 270  D E C E M B E R         25             Holmes & Watson
# 271  D E C E M B E R         25                        Vice
# 272  D E C E M B E R         25         On the Basis of Sex
# 273  D E C E M B E R         25                   Destroyer
# 274  D E C E M B E R         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                        Momentum Pictures / GFM Films
# ...

# %%
# !pip install tmdbv3api

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'd766fa2d012d94a998f49d4dbbae0a1f'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#              Opening  Opening.1                       Title  \
# 0      J A N U A R Y          5     Insidious: The Last Key
# 1      J A N U A R Y          5            The Strange Ones
# 2      J A N U A R Y          5                    Stratton
# 3      J A N U A R Y         10               Sweet Country
# 4      J A N U A R Y         12                The Commuter
# ..               ...        ...                         ...
# 270  D E C E M B E R         25             Holmes & Watson
# 271  D E C E M B E R         25                        Vice
# 272  D E C E M B E R         25         On the Basis of Sex
# 273  D E C E M B E R         25                   Destroyer
# 274  D E C E M B E R         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                        Momentum Pictures / GFM Films
# ...

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 270             Holmes & Watson
# 271                        Vice
# 272         On the Basis of Sex
# 273                   Destroyer
# 274  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 270  Etan Cohen (director/screenplay); Will Ferrell...
# 271  Adam McKay (director/screenplay); Christian Ba...
# 272  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\930721595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 270             Holmes & Watson
# 271                        Vice
# 272         On the Basis of Sex
# 273                   Destroyer
# 274  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 270  Etan Cohen (director/screenplay); Will Ferrell...
# 271  Adam McKay (director/screenplay); Christian Ba...
# 272  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\2274966287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 270             Holmes & Watson
# 271                        Vice
# 272         On the Basis of Sex
# 273                   Destroyer
# 274  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 270  Etan Cohen (director/screenplay); Will Ferrell...
# 271  Adam McKay (director/screenplay); Christian Ba...
# 272  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\3672495884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\2517195254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 270             Holmes & Watson
# 271                        Vice
# 272         On the Basis of Sex
# 273                   Destroyer
# 274  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 270  Etan Cohen (director/screenplay); Will Ferrell...
# 271  Adam McKay (director/screenplay); Christian Ba...
# 272  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 270          Etan Cohen     Will Ferrell          John C. Reilly
# 271          Adam McKay   Christian Bale               Amy Adams
# 272          Mimi Leder   Felicity Jones            Armie Hammer
# 273        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 274         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 270          Etan Cohen     Will Ferrell          John C. Reilly
# 271          Adam McKay   Christian Bale               Amy Adams
# 272          Mimi Leder   Felicity Jones            Armie Hammer
# 273        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 274         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %% [markdown]
# ## Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1              Title  \
# 0      J A N U A R Y          4        Escape Room
# 1      J A N U A R Y          4         Rust Creek
# 2      J A N U A R Y          4   American Hangman
# 3      J A N U A R Y         11   A Dog's Way Home
# 4      J A N U A R Y         11         The Upside
# ..               ...        ...                ...
# 240  D E C E M B E R         25  Spies in Disguise
# 241  D E C E M B E R         25       Little Women
# 242  D E C E M B E R         25               1917
# 243  D E C E M B E R         25         Just Mercy
# 244  D E C E M B E R         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ...

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 240  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 241       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 242               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 243         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 244           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\203239715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1562076556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\3736213850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 240  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 241            Greta Gerwig        Saoirse Ronan           Emma Watson
# 242              Sam Mendes        George MacKay  Dean-Charles Chapman
# 243   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 244         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# ...

# %%
my_df
# Out:
#               director_name       actor_1_name            actor_2_name  \
# 0              Adam Robitel          Lin Shaye           Angus Sampson
# 1          Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2                Simon West     Dominic Cooper          Austin Stowell
# 3          Warwick Thornton        Bryan Brown               Sam Neill
# 4        Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                      ...                ...                     ...
# 515  Nick Bruno, Troy Quane         Will Smith             Tom Holland
# 516            Greta Gerwig      Saoirse Ronan             Emma Watson
# 517              Sam Mendes      George MacKay    Dean-Charles Chapman
# 518   Destin Daniel Cretton  Michael B. Jordan              Jamie Foxx
# 519         Chinonye Chukwu      Alfre Woodard          Wendell Pierce
#
#        actor_3_name                                    genres  \
# ...

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# ...

# %%
final_df = old_df.append(my_df,ignore_index=True)
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\2046453413.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5879  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5880            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5881              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5882   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5883         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# ...

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('final_data.csv',index=False)

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link3 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
df1 = pd.read_html(link3, header=0)[2]
df2 = pd.read_html(link3, header=0)[3]
df3 = pd.read_html(link3, header=0)[4]
df4 = pd.read_html(link3, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          3             The Grudge
# 1      J A N U A R Y         10             Underwater
# 2      J A N U A R Y         10            Like a Boss
# 3      J A N U A R Y         10          Three Christs
# 4      J A N U A R Y         10      Inherit the Viper
# ..               ...        ...                    ...
# 270  D E C E M B E R         25       We Can Be Heroes
# 271  D E C E M B E R         25      News of the World
# 272  D E C E M B E R         25  One Night in Miami...
# 273  D E C E M B E R         25  Promising Young Woman
# 274  D E C E M B E R         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# ...

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [275 rows x 2 columns]

# %%
def get_genre1(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre1(str(x)))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\2499978658.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre1(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# ...

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\3962101783.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1815024756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\3667490226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# ...

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 270  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 271   Paul Greengrass              Tom Hanks      Helena Zengel
# 272       Regina King      Kingsley Ben-Adir          Eli Goree
# 273   Emerald Fennell         Carey Mulligan         Bo Burnham
# 274  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                   genres  \
# 0           John Cho                           Horror Mystery
# 1    Jessica Henwick  Horror Science Fiction Action Adventure
# ...

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      5
# actor_3_name     28
# genres            2
# movie_title       0
# comb             29
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\117998293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 269       Pete Docter             Jamie Foxx           Tina Fey
# 270  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 272       Regina King      Kingsley Ben-Adir          Eli Goree
# 273   Emerald Fennell         Carey Mulligan         Bo Burnham
# 274  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                   genres  \
# 0           John Cho                           Horror Mystery
# 1    Jessica Henwick  Horror Science Fiction Action Adventure
# ...

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5879  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5880            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5881              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5882   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5883         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# ...

# %%
final_df = old_df.append(new_df20,ignore_index=True)
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1526179653.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 6125        Pete Docter             Jamie Foxx          Tina Fey
# 6126   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 6127        Regina King      Kingsley Ben-Adir         Eli Goree
# 6128    Emerald Fennell         Carey Mulligan        Bo Burnham
# 6129   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                                 genres  \
# 0                Wes Studi        Action Adventure Fantasy Sci-Fi
# ...

# %%
final_df.to_csv('main_data.csv',index=False)

# %% [markdown]
# ## Extracting features of 2021 movies from Wikipedia

# %%
link4 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %%
df1 = pd.read_html(link4, header=0)[2]
df2 = pd.read_html(link4, header=0)[3]
df3 = pd.read_html(link4, header=0)[4]
df4 = pd.read_html(link4, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                   Title  \
# 0      J A N U A R Y        1.0     Shadow in the Cloud
# 1      J A N U A R Y       13.0         The White Tiger
# 2      J A N U A R Y       14.0             Locked Down
# 3      J A N U A R Y       15.0                 The Dig
# 4      J A N U A R Y       15.0        Outside the Wire
# ..               ...        ...                     ...
# 356  D E C E M B E R       25.0  The Tragedy of Macbeth
# 357  D E C E M B E R       25.0    A Journal for Jordan
# 358  D E C E M B E R       25.0       American Underdog
# 359  D E C E M B E R       26.0                 Memoria
# 360  D E C E M B E R        NaN                     NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                                Netflix / Noruz Films
# 2                      HBO Max / Warner Bros. Pictures
# 3                          Netflix / Clerkenwell Films
# ...

# %%
df['genres'] = df['Title'].map(lambda x: get_genre1(str(x)))

# %%
df
# Out:
#              Opening  Opening.1                   Title  \
# 0      J A N U A R Y        1.0     Shadow in the Cloud
# 1      J A N U A R Y       13.0         The White Tiger
# 2      J A N U A R Y       14.0             Locked Down
# 3      J A N U A R Y       15.0                 The Dig
# 4      J A N U A R Y       15.0        Outside the Wire
# ..               ...        ...                     ...
# 356  D E C E M B E R       25.0  The Tragedy of Macbeth
# 357  D E C E M B E R       25.0    A Journal for Jordan
# 358  D E C E M B E R       25.0       American Underdog
# 359  D E C E M B E R       26.0                 Memoria
# 360  D E C E M B E R        NaN                     NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                                Netflix / Noruz Films
# 2                      HBO Max / Warner Bros. Pictures
# 3                          Netflix / Clerkenwell Films
# ...

# %%
df_2021 = df[['Title','Cast and crew','genres']]

# %%
df_2021
# Out:
#                       Title  \
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 356  The Tragedy of Macbeth
# 357    A Journal for Jordan
# 358       American Underdog
# 359                 Memoria
# 360                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 356  Joel Coen (director/screenplay); Denzel Washin...
# 357  Denzel Washington (director); Virgil Williams ...
# 358  Erwin brothers (directors); Jon Erwin, David A...
# 359  Apichatpong Weerasethakul (director/acreenplay...
# ...

# %%
def get_director1(x):
    if pd.isna(x):
        return None
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director1(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\2981887549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director1(x))

# %%
def get_actor1_1(x):
    if pd.isna(x):
        return None
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
def get_actor2_2(x):
    if pd.isna(x):
        return np.NaN
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
def get_actor3_3(x):
    if pd.isna(x):
        return np.NaN    
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1_1(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1102623037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1_1(x))

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2_2(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1675635709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2_2(x))

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3_3(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\3148803455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3_3(x))

# %%
df_2021
# Out:
#                       Title  \
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 356  The Tragedy of Macbeth
# 357    A Journal for Jordan
# 358       American Underdog
# 359                 Memoria
# 360                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 356  Joel Coen (director/screenplay); Denzel Washin...
# 357  Denzel Washington (director); Virgil Williams ...
# 358  Erwin brothers (directors); Jon Erwin, David A...
# 359  Apichatpong Weerasethakul (director/acreenplay...
# ...

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 356                                          Joel Coen
# 357                                  Denzel Washington
# 358                                     Erwin brothers
# 359  Apichatpong Weerasethakul (director/acreenplay...
# 360                                               None
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# ...

# %%
new_df21['actor_2_name'] = new_df21['actor_2_name'].replace(np.nan, 'unknown')
new_df21['actor_3_name'] = new_df21['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df21['movie_title'] = new_df21['movie_title'].str.lower()

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']

# %%
new_df21
# Out:
#                             director_name       actor_1_name  \
# 0                           Simon Kinberg   Jessica Chastain
# 1                  Patricia Harris Seeley      Autumn Reeser
# 2                              Asif Akbar      Mickey Rourke
# 3                            Edward Drake  Timothy V. Murphy
# 4    Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera
# ..                                    ...                ...
# 319                       Damien Chazelle          Brad Pitt
# 320                          Kasi Lemmons        Naomi Ackie
# 321                          Scott Cooper     Christian Bale
# 322                          Sarah Polley        Rooney Mara
# 323                          Marc Forster          Tom Hanks
#
#           actor_2_name      actor_3_name                           genres  \
# 0       Lupita Nyong'o     Penélope Cruz                  Action Thriller
# 1         Antonio Cupo       Danny Trejo  Family Animation Fantasy Horror
# ...

# %%
new_df21 = new_df21[new_df21['movie_title'] != 'memoria']

# %%
new_df21.drop(36, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[237], line 1
# ----> 1 new_df21.drop(360, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
new_df21
# Out:
#          director_name        actor_1_name       actor_2_name  \
# 0       Roseanne Liang  Chloë Grace Moretz  Taylor John Smith
# 1        Ramin Bahrani       Adarsh Gourav      Rajkummar Rao
# 2           Doug Liman       Anne Hathaway   Chiwetel Ejiofor
# 3          Simon Stone      Carey Mulligan      Ralph Fiennes
# 4      Mikael Håfström      Anthony Mackie       Damson Idris
# ..                 ...                 ...                ...
# 355     Matthew Vaughn       Ralph Fiennes     Gemma Arterton
# 356          Joel Coen   Denzel Washington  Frances McDormand
# 357  Denzel Washington   Michael B. Jordan       Chanté Adams
# 358     Erwin brothers        Zachary Levi        Anna Paquin
# 360               None                None            unknown
#
#               actor_3_name                           genres  \
# 0             Beulah Koale                Horror Action War
# 1    Priyanka Chopra Jonas                            Drama
# ...

# %% [markdown]
# ## Extracting features of 2022 movies from Wikipedia

# %%
link5 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"

# %%
df1 = pd.read_html(link5, header=0)[2]
df2 = pd.read_html(link5, header=0)[3]
df3 = pd.read_html(link5, header=0)[4]
df4 = pd.read_html(link5, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                     Title  \
# 0      J A N U A R Y        7.0                   The 355
# 1      J A N U A R Y        7.0  The Legend of La Llorona
# 2      J A N U A R Y        7.0              The Commando
# 3      J A N U A R Y        7.0            American Siege
# 4      J A N U A R Y       14.0                    Scream
# ..               ...        ...                       ...
# 324  D E C E M B E R       30.0            Alice, Darling
# 325  D E C E M B E R        NaN                       NaN
# 326  D E C E M B E R        NaN                       NaN
# 327  D E C E M B E R        NaN                       NaN
# 328  D E C E M B E R        NaN                       NaN
#
#                                     Production company  \
# 0    Universal Pictures / Freckle Films / FilmNatio...
# 1                       Saban Films / Ageless Pictures
# 2                 Saban Films / Premiere Entertainment
# ...

# %%
df.drop([324, 325, 326, 327,328], inplace=True)

# %%
df
# Out:
#              Opening  Opening.1                                         Title  \
# 0      J A N U A R Y        7.0                                       The 355
# 1      J A N U A R Y        7.0                      The Legend of La Llorona
# 2      J A N U A R Y        7.0                                  The Commando
# 3      J A N U A R Y        7.0                                American Siege
# 4      J A N U A R Y       14.0                                        Scream
# ..               ...        ...                                           ...
# 319  D E C E M B E R       23.0                                       Babylon
# 320  D E C E M B E R       23.0  Whitney Houston: I Wanna Dance with Somebody
# 321  D E C E M B E R       23.0                             The Pale Blue Eye
# 322  D E C E M B E R       23.0                                 Women Talking
# 323  D E C E M B E R       29.0                             A Man Called Otto
#
# ...

# %%
df['genres'] = df['Title'].map(lambda x: get_genre1(str(x)))

# %%
df
# Out:
#              Opening  Opening.1                                         Title  \
# 0      J A N U A R Y        7.0                                       The 355
# 1      J A N U A R Y        7.0                      The Legend of La Llorona
# 2      J A N U A R Y        7.0                                  The Commando
# 3      J A N U A R Y        7.0                                American Siege
# 4      J A N U A R Y       14.0                                        Scream
# ..               ...        ...                                           ...
# 319  D E C E M B E R       23.0                                       Babylon
# 320  D E C E M B E R       23.0  Whitney Houston: I Wanna Dance with Somebody
# 321  D E C E M B E R       23.0                             The Pale Blue Eye
# 322  D E C E M B E R       23.0                                 Women Talking
# 323  D E C E M B E R       29.0                             A Man Called Otto
#
# ...

# %%
df_2022 = df[['Title','Cast and crew','genres']]

# %%
df_2022
# Out:
#                                             Title  \
# 0                                         The 355
# 1                        The Legend of La Llorona
# 2                                    The Commando
# 3                                  American Siege
# 4                                          Scream
# ..                                            ...
# 319                                       Babylon
# 320  Whitney Houston: I Wanna Dance with Somebody
# 321                             The Pale Blue Eye
# 322                                 Women Talking
# 323                             A Man Called Otto
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ...

# %%
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1906082619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2022
# Out:
#                                             Title  \
# 0                                         The 355
# 1                        The Legend of La Llorona
# 2                                    The Commando
# 3                                  American Siege
# 4                                          Scream
# ..                                            ...
# 319                                       Babylon
# 320  Whitney Houston: I Wanna Dance with Somebody
# 321                             The Pale Blue Eye
# 322                                 Women Talking
# 323                             A Man Called Otto
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ...

# %%
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1_1(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\3696505166.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1_1(x))

# %%
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2_2(x))
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3_3(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1279649448.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2_2(x))
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1279649448.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3_3(x))

# %%
df_2022
# Out:
#                                             Title  \
# 0                                         The 355
# 1                        The Legend of La Llorona
# 2                                    The Commando
# 3                                  American Siege
# 4                                          Scream
# ..                                            ...
# 319                                       Babylon
# 320  Whitney Houston: I Wanna Dance with Somebody
# 321                             The Pale Blue Eye
# 322                                 Women Talking
# 323                             A Man Called Otto
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ...

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df22
# Out:
#                             director_name       actor_1_name  \
# 0                           Simon Kinberg   Jessica Chastain
# 1                  Patricia Harris Seeley      Autumn Reeser
# 2                              Asif Akbar      Mickey Rourke
# 3                            Edward Drake  Timothy V. Murphy
# 4    Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera
# ..                                    ...                ...
# 319                       Damien Chazelle          Brad Pitt
# 320                          Kasi Lemmons        Naomi Ackie
# 321                          Scott Cooper     Christian Bale
# 322                          Sarah Polley        Rooney Mara
# 323                          Marc Forster          Tom Hanks
#
#           actor_2_name      actor_3_name                           genres  \
# 0       Lupita Nyong'o     Penélope Cruz                  Action Thriller
# 1         Antonio Cupo       Danny Trejo  Family Animation Fantasy Horror
# ...

# %%
new_df22['actor_2_name'] = new_df22['actor_2_name'].replace(np.nan, 'unknown')
new_df22['actor_3_name'] = new_df22['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df22['actor_3_name'] + ' '+ new_df22['director_name'] +' ' + new_df22['genres']

# %%
new_df22
# Out:
#                             director_name       actor_1_name  \
# 0                           Simon Kinberg   Jessica Chastain
# 1                  Patricia Harris Seeley      Autumn Reeser
# 2                              Asif Akbar      Mickey Rourke
# 3                            Edward Drake  Timothy V. Murphy
# 4    Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera
# ..                                    ...                ...
# 319                       Damien Chazelle          Brad Pitt
# 320                          Kasi Lemmons        Naomi Ackie
# 321                          Scott Cooper     Christian Bale
# 322                          Sarah Polley        Rooney Mara
# 323                          Marc Forster          Tom Hanks
#
#           actor_2_name      actor_3_name                           genres  \
# 0       Lupita Nyong'o     Penélope Cruz                  Action Thriller
# 1         Antonio Cupo       Danny Trejo  Family Animation Fantasy Horror
# ...

# %% [markdown]
# ## Extracting features of 2023 movies from Wikipedia

# %%
link6 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2023"

# %%
df1 = pd.read_html(link6, header=0)[2]
df2 = pd.read_html(link6, header=0)[3]
df3 = pd.read_html(link6, header=0)[4]
df4 = pd.read_html(link6, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#      Rank                               Title Distributor Domestic gross  \
# 0     1.0        The Super Mario Bros. Movie*   Universal   $560,893,170
# 1     2.0     Guardians of the Galaxy Vol. 3*      Disney   $306,304,761
# 2     3.0  Ant-Man and the Wasp: Quantumania*      Disney   $214,455,625
# 3     4.0               John Wick: Chapter 4*   Lionsgate   $186,531,016
# 4     5.0                           Creed III         MGM   $156,248,615
# ..    ...                                 ...         ...            ...
# 184   NaN                   The Expendables 4         NaN            NaN
# 185   NaN                The Book of Clarence         NaN            NaN
# 186   NaN                    Drive-Away Dolls         NaN            NaN
# 187   NaN        PAW Patrol: The Mighty Movie         NaN            NaN
# 188   NaN                         The Creator         NaN            NaN
#
#                Opening  Opening.1  \
# 0                  NaN        NaN
# ...

# %%
df.drop(df.index[0:10], inplace=True)

# %%
df
# Out:
#      Rank                         Title Distributor Domestic gross  \
# 10    NaN                         M3GAN         NaN            NaN
# 11    NaN                   The Old Way         NaN            NaN
# 12    NaN          The Devil Conspiracy         NaN            NaN
# 13    NaN                         Plane         NaN            NaN
# 14    NaN                   House Party         NaN            NaN
# ..    ...                           ...         ...            ...
# 184   NaN             The Expendables 4         NaN            NaN
# 185   NaN          The Book of Clarence         NaN            NaN
# 186   NaN              Drive-Away Dolls         NaN            NaN
# 187   NaN  PAW Patrol: The Mighty Movie         NaN            NaN
# 188   NaN                   The Creator         NaN            NaN
#
#                Opening  Opening.1  \
# 10       J A N U A R Y        6.0
# 11       J A N U A R Y        6.0
# 12       J A N U A R Y       11.0
# ...

# %%
df['genres'] = df['Title'].map(lambda x: get_genre1(str(x)))

# %%
df_2023 = df[['Title','Cast and crew','genres']]

# %%
df_2023
# Out:
#                             Title  \
# 10                          M3GAN
# 11                    The Old Way
# 12           The Devil Conspiracy
# 13                          Plane
# 14                    House Party
# ..                            ...
# 184             The Expendables 4
# 185          The Book of Clarence
# 186              Drive-Away Dolls
# 187  PAW Patrol: The Mighty Movie
# 188                   The Creator
#
#                                          Cast and crew  \
# 10   Gerard Johnstone (director); Akela Cooper (scr...
# 11   Brett Donowho (director); Carl W. Lucas (scree...
# 12   Nathan Frankowski (director); Ed Alan (screenp...
# 13   Jean-François Richet (director); Charles Cummi...
# 14   Calmatic (director); Jamal Olori, Stephen Glov...
# ..                                                 ...
# 184  Scott Waugh (director); Spenser Cohen, Max Ada...
# 185  Jeymes Samuel (director/screenplay); LaKeith S...
# ...

# %%
df_2023['director_name'] = df_2023['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\1551818249.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['director_name'] = df_2023['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
df_2023['actor_1_name'] = df_2023['Cast and crew'].map(lambda x: get_actor1_1(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\4061781682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['actor_1_name'] = df_2023['Cast and crew'].map(lambda x: get_actor1_1(x))

# %%
df_2023['actor_2_name'] = df_2023['Cast and crew'].map(lambda x: get_actor2_2(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\4033021046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['actor_2_name'] = df_2023['Cast and crew'].map(lambda x: get_actor2_2(x))

# %%
df_2023['actor_3_name'] = df_2023['Cast and crew'].map(lambda x: get_actor3_3(x))
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\60191886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['actor_3_name'] = df_2023['Cast and crew'].map(lambda x: get_actor3_3(x))

# %%
df_2023 = df_2023.rename(columns={'Title':'movie_title'})

# %%
new_df23 = df_2023.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
nan_count = new_df23.isna().sum()
print(nan_count)
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     1
# actor_3_name     9
# genres           0
# movie_title      0
# dtype: int64

# %%
new_df23['actor_2_name'] = new_df23['actor_2_name'].replace(np.nan, 'unknown')
new_df23['actor_3_name'] = new_df23['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df23['movie_title'] = new_df23['movie_title'].str.lower()

# %%
new_df23['comb'] = new_df23['actor_1_name'] + ' ' + new_df23['actor_2_name'] + ' '+ new_df23['actor_3_name'] + ' '+ new_df23['director_name'] +' ' + new_df23['genres']

# %%
new_df23
# Out:
#             director_name                           actor_1_name  \
# 10       Gerard Johnstone                       Allison Williams
# 11          Brett Donowho                           Nicolas Cage
# 12      Nathan Frankowski                        Alice Orr-Ewing
# 13   Jean-François Richet                          Gerard Butler
# 14               Calmatic                             Tosin Cole
# ..                    ...                                    ...
# 184           Scott Waugh                          Jason Statham
# 185         Jeymes Samuel                      LaKeith Stanfield
# 186            Ethan Coen                       Margaret Qualley
# 187           Cal Brunker  Cal Brunker (director); Mckenna Grace
# 188        Gareth Edwards                  John David Washington
#
#               actor_2_name      actor_3_name  \
# 10           Violet McGraw       Amie Donald
# 11    Ryan Kiera Armstrong           unknown
# 12               Joe Doyle      Eveline Hall
# ...

# %%
combined_df = pd.concat([new_df23, new_df22], axis=0)

# %%
combined_df
# Out:
#             director_name      actor_1_name          actor_2_name  \
# 10       Gerard Johnstone  Allison Williams         Violet McGraw
# 11          Brett Donowho      Nicolas Cage  Ryan Kiera Armstrong
# 12      Nathan Frankowski   Alice Orr-Ewing             Joe Doyle
# 13   Jean-François Richet     Gerard Butler           Mike Colter
# 14               Calmatic        Tosin Cole        Jacob Latimore
# ..                    ...               ...                   ...
# 319       Damien Chazelle         Brad Pitt         Margot Robbie
# 320          Kasi Lemmons       Naomi Ackie         Stanley Tucci
# 321          Scott Cooper    Christian Bale         Harry Melling
# 322          Sarah Polley       Rooney Mara            Claire Foy
# 323          Marc Forster         Tom Hanks       Mariana Treviño
#
#          actor_3_name                                   genres  \
# 10        Amie Donald            Science Fiction Horror Comedy
# ...

# %%
my_df = new_df22.append(new_df23,ignore_index=True)
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\2867938759.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   my_df = new_df22.append(new_df23,ignore_index=True)

# %%
my_df
# Out:
#                             director_name  \
# 0                           Simon Kinberg
# 1                  Patricia Harris Seeley
# 2                              Asif Akbar
# 3                            Edward Drake
# 4    Matt Bettinelli-Olpin, Tyler Gillett
# ..                                    ...
# 498                           Scott Waugh
# 499                         Jeymes Samuel
# 500                            Ethan Coen
# 501                           Cal Brunker
# 502                        Gareth Edwards
#
#                               actor_1_name           actor_2_name  \
# 0                         Jessica Chastain         Lupita Nyong'o
# 1                            Autumn Reeser           Antonio Cupo
# 2                            Mickey Rourke      Michael Jai White
# 3                        Timothy V. Murphy           Bruce Willis
# 4                          Melissa Barrera          Mason Gooding
# ...

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# ...

# %%
combined_df = df1.append([new_df18, new_df19,new_df20 , new_df21, new_df22 , new_df23], ignore_index=True)
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\334526874.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = df1.append([new_df18, new_df19,new_df20 , new_df21, new_df22 , new_df23], ignore_index=True)

# %%
combined_df
# Out:
#       Rank                               Title Distributor Domestic gross  \
# 0      1.0        The Super Mario Bros. Movie*   Universal   $560,893,170
# 1      2.0     Guardians of the Galaxy Vol. 3*      Disney   $306,304,761
# 2      3.0  Ant-Man and the Wasp: Quantumania*      Disney   $214,455,625
# 3      4.0               John Wick: Chapter 4*   Lionsgate   $186,531,016
# 4      5.0                           Creed III         MGM   $156,248,615
# ...    ...                                 ...         ...            ...
# 1598   NaN                                 NaN         NaN            NaN
# 1599   NaN                                 NaN         NaN            NaN
# 1600   NaN                                 NaN         NaN            NaN
# 1601   NaN                                 NaN         NaN            NaN
# 1602   NaN                                 NaN         NaN            NaN
#
#        director_name                           actor_1_name  \
# ...

# %%
final_df = old_df.append(combined_df,ignore_index=True)
# Out:
# C:\Users\Yassine\AppData\Local\Temp\ipykernel_13028\4181883658.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(combined_df,ignore_index=True)

# %%
final_df
# Out:
#           director_name                           actor_1_name  \
# 0         James Cameron                            CCH Pounder
# 1        Gore Verbinski                            Johnny Depp
# 2            Sam Mendes                        Christoph Waltz
# 3     Christopher Nolan                              Tom Hardy
# 4           Doug Walker                            Doug Walker
# ...                 ...                                    ...
# 6962        Scott Waugh                          Jason Statham
# 6963      Jeymes Samuel                      LaKeith Stanfield
# 6964         Ethan Coen                       Margaret Qualley
# 6965        Cal Brunker  Cal Brunker (director); Mckenna Grace
# 6966     Gareth Edwards                  John David Washington
#
#                actor_2_name          actor_3_name  \
# 0          Joel David Moore             Wes Studi
# 1             Orlando Bloom        Jack Davenport
# 2              Rory Kinnear      Stephanie Sigman
# ...

# %%
final_df.to_csv('main_data.csv',index=False)
